# %% [markdown]
# # Overall steps to use our repo
#
# 1. Make a token on your personal git which is required for push
# 2. Use the token to clone the repo
# 3. Create your personal branch on the git
# 4. Push something to your branch

# %% [markdown]
# # Generate token
#
# Steps to create a PAT:
#
# - Go to your GitHub account.
# - In the top-right corner, click your profile picture, and then - - click Settings.
# - In the left sidebar, click Developer settings.
# - Under Developer settings, click Personal access tokens.
# - Click Generate new token.
# - Give it a name (e.g., colab-token), select the scopes (e.g., repo), and click Generate token.
# Copy the token (you won't be able to see it again once you leave this page

# %%
# clone the repo using ur github username + token
# !git clone https://yourusername:ghp_abcdefghijklmnopqrstuvwxyz123456@github.com/Mehrdad-hajizadeh/Kaggle_LLM_competition.git

# %%
# go to cloned directory and make a branch
# %cd Kaggle_LLM_competition/
# !git checkout -b YOUNAME_branch

# %%
# see the satus of the branch
# !git status

# %%
# add . as an example.
# Note: if you want to add a new file to the repo, you need first copy the file to cloned repo.
#Then, you can use add command to add that file to repo
# !git add .

# %%
# Optional: u can use it to allow rememeber your token
# !git config --global credential.helper cache

# %%
# make a commit befor any push
# !git commit -m "Hello Commit"

# %%
# push to your own branch, whatever you name it above
# !git push origin YOUNAME_branch

# %%
# !git commit -m "notebook update"
#!git add kaggle.ipynb
#!git push origin Mehrdad_branch
# Out:
# On branch Mehrdad_branch
# nothing to commit, working tree clean
